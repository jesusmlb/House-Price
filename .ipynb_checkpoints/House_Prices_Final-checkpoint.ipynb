# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import warnings
warnings.filterwarnings('ignore')
import category_encoders as ce


#Modeling
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.stats import pearsonr
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import ElasticNetCV
from sklearn import svm
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
import lightgbm as lgb
import catboost as cb

#Metrics
from sklearn.metrics import r2_score 
from sklearn import metrics 
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

import statsmodels.regression.linear_model as sm
from statsmodels.api import add_constant
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

df = pd.read_csv('/Users/jesuslopez/Downloads/train (1).csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.iloc[:, :40].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1460 non-null   int64
#  1   MSSubClass    1460 non-null   int64
#  2   MSZoning      1460 non-null   object
#  3   LotFrontage   1201 non-null   float64
#  4   LotArea       1460 non-null   int64
#  5   Street        1460 non-null   object
#  6   Alley         91 non-null     object
#  7   LotShape      1460 non-null   object
#  8   LandContour   1460 non-null   object
#  9   Utilities     1460 non-null   object
#  10  LotConfig     1460 non-null   object
#  11  LandSlope     1460 non-null   object
#  12  Neighborhood  1460 non-null   object
#  13  Condition1    1460 non-null   object
#  14  Condition2    1460 non-null   object
#  15  BldgType      1460 non-null   object
#  16  HouseStyle    1460 non-null   object
#  17  OverallQual   1460 non-null   int64
# ...

# %%
df.iloc[:, 40:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 41 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   HeatingQC      1460 non-null   object
#  1   CentralAir     1460 non-null   object
#  2   Electrical     1459 non-null   object
#  3   1stFlrSF       1460 non-null   int64
#  4   2ndFlrSF       1460 non-null   int64
#  5   LowQualFinSF   1460 non-null   int64
#  6   GrLivArea      1460 non-null   int64
#  7   BsmtFullBath   1460 non-null   int64
#  8   BsmtHalfBath   1460 non-null   int64
#  9   FullBath       1460 non-null   int64
#  10  HalfBath       1460 non-null   int64
#  11  BedroomAbvGr   1460 non-null   int64
#  12  KitchenAbvGr   1460 non-null   int64
#  13  KitchenQual    1460 non-null   object
#  14  TotRmsAbvGrd   1460 non-null   int64
#  15  Functional     1460 non-null   object
#  16  Fireplaces     1460 non-null   int64
#  17  FireplaceQu    770 non-null    object
# ...

# %%
df = df.fillna(df.select_dtypes(include=['float64']).median())

# %%
df.iloc[:, :40].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            1460 non-null   int64
#  1   MSSubClass    1460 non-null   int64
#  2   MSZoning      1460 non-null   object
#  3   LotFrontage   1460 non-null   float64
#  4   LotArea       1460 non-null   int64
#  5   Street        1460 non-null   object
#  6   Alley         91 non-null     object
#  7   LotShape      1460 non-null   object
#  8   LandContour   1460 non-null   object
#  9   Utilities     1460 non-null   object
#  10  LotConfig     1460 non-null   object
#  11  LandSlope     1460 non-null   object
#  12  Neighborhood  1460 non-null   object
#  13  Condition1    1460 non-null   object
#  14  Condition2    1460 non-null   object
#  15  BldgType      1460 non-null   object
#  16  HouseStyle    1460 non-null   object
#  17  OverallQual   1460 non-null   int64
# ...

# %%
df.BsmtQual = df.BsmtQual.fillna('None')
encoder = ce.OrdinalEncoder(cols=['BsmtQual'],return_df=True,
                           mapping=[{'col':'BsmtQual',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df['BsmtQual'] = encoder.fit_transform(df['BsmtQual'])

# %%
df.Alley = df.Alley.fillna('NoAll')

# %%
df.Electrical = df.Electrical.fillna('SBrkr') #To the most common electrical system

# %%
df.BFireplaceQu = df.FireplaceQu.fillna('None')
encoder = ce.OrdinalEncoder(cols=['FireplaceQu'],return_df=True,
                           mapping=[{'col':'FireplaceQu',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df['FireplaceQu'] = encoder.fit_transform(df['FireplaceQu'])

# %%
df.GarageType = df.GarageType.fillna('NG') #NaN mean No garage, so let's replace with NG = No Garage

# %%
df.GarageFinish = df.GarageFinish.fillna('NG') #NaN mean No garage, so let's replace with NG = No Garage

# %%
df.PoolQC = df.PoolQC.fillna('None')
encoder = ce.OrdinalEncoder(cols=['PoolQC'],return_df=True,
                           mapping=[{'col':'PoolQC',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df['PoolQC'] = encoder.fit_transform(df['PoolQC'])

# %%
df.ExterQual = df.ExterQual.fillna('None')
encoder = ce.OrdinalEncoder(cols=['ExterQual'],return_df=True,
                           mapping=[{'col':'ExterQual',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df['ExterQual'] = encoder.fit_transform(df['ExterQual'])

# %%
df.HeatingQC = df.HeatingQC.fillna('None')
encoder = ce.OrdinalEncoder(cols=['HeatingQC'],return_df=True,
                           mapping=[{'col':'HeatingQC',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df['HeatingQC'] = encoder.fit_transform(df['HeatingQC'])

# %%
df.KitchenQual = df.KitchenQual.fillna('None')
encoder = ce.OrdinalEncoder(cols=['KitchenQual'],return_df=True,
                           mapping=[{'col':'KitchenQual',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df['KitchenQual'] = encoder.fit_transform(df['KitchenQual'])

# %%
encoder = ce.OrdinalEncoder(cols=['CentralAir'],return_df=True,
                           mapping=[{'col':'CentralAir',
'mapping':{'N':0, 'Y':1}}])
df['CentralAir'] = encoder.fit_transform(df['CentralAir'])

# %%
df.Fence = df.Fence.fillna('NoF')
df.MiscFeature = df.MiscFeature.fillna('None')
df.MasVnrType = df.MasVnrType.fillna('None')

# %%
df['TotalBath'] = df[['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath']].sum(axis=1)
df = df.drop(columns=['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BedroomAbvGr', 'KitchenAbvGr', 'GarageArea', 'GarageQual', 'GarageCond', 'MoSold'])

# %%
df.shape
# Out:
# (1460, 63)

# %% [markdown]
# #### Outliers

# %%
df = df.loc[df['LotArea'] < 30000] #We decide to trim outliers because doesn't represent more than 3% of the data
df = df.loc[df['LotFrontage'] < 200] #Same, we just have one datapoint
df = df.loc[df['SalePrice'] < 500000]

# %% [markdown]
# ## Explotaroy Data Analysis

# %%
df_obj = df.select_dtypes('object')
colum_header = list(df_obj.columns.values) #Categorical variables

# %%
columns = 3

fig, axes = plt.subplots(len(colum_header) //columns, columns, figsize=(30,30))

for current_idx, variable in enumerate(colum_header):
   
    i = current_idx // columns # Filas
    j = current_idx % columns  # Columnas

    sns.boxplot(x=df['SalePrice'], y=df_obj[variable], ax=axes[i][j])
    sns.boxplot(x=df['SalePrice'], y=df_obj[variable], ax=axes[i][j])

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df['Utilities'].value_counts() #As we can see there is just one 'NoSeWa', It is a unbalanced variable, we proceed to eliminate it.
df = df.drop(columns=['Utilities'])

# %% [markdown]
# Let's evaluate correlation between our numerical values

# %%
df_obj = df.select_dtypes(['int', 'float'])
colum_header = list(df_obj.columns.values) #Categorical variables

# %%
columns = 4
fig, axes = plt.subplots(len(colum_header) //columns, columns, figsize=(30,30))

for current_idx, variable in enumerate(colum_header):
   
    i = current_idx // columns # Filas
    j = current_idx % columns  # Columnas

    sns.histplot(df[variable], ax=axes[i][j])
    sns.histplot(df[variable], ax=axes[i][j])

plt.tight_layout()
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [31], in <cell line: 4>()
#       6     i = current_idx // columns # Filas
#       7     j = current_idx % columns  # Columnas
# ----> 9     sns.histplot(df[variable], ax=axes[i][j])
#      10     sns.histplot(df[variable], ax=axes[i][j])
#      12 plt.tight_layout()
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
df['SalePrice'].mean()
# Out:
# 177338.75104895106

# %%
corr_matrix = df.corr()
corr_matrix["SalePrice"].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# OverallQual      0.813138
# GrLivArea        0.715270
# ExterQual        0.703519
# KitchenQual      0.674040
# GarageCars       0.658299
# TotalBsmtSF      0.632459
# TotalBath        0.615208
# BsmtQual         0.596345
# YearBuilt        0.553677
# YearRemodAdd     0.538666
# FireplaceQu      0.528958
# TotRmsAbvGrd     0.521911
# GarageYrBlt      0.496982
# Fireplaces       0.467774
# HeatingQC        0.454634
# MasVnrArea       0.446840
# LotArea          0.385473
# LotFrontage      0.348075
# OpenPorchSF      0.342522
# WoodDeckSF       0.322438
# CentralAir       0.269190
# BsmtUnfSF        0.235349
# ScreenPorch      0.100776
# 3SsnPorch        0.055983
# PoolArea         0.037852
# PoolQC           0.037070
# MiscVal         -0.021058
# Id              -0.023888
# YrSold          -0.035964
# OverallCond     -0.077233
# MSSubClass      -0.080750
# EnclosedPorch   -0.127362
# Name: SalePrice, dtype: float64

# %%
df.iloc[:, 40:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1430 entries, 0 to 1459
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fireplaces     1430 non-null   int64
#  1   FireplaceQu    1430 non-null   float64
#  2   GarageType     1430 non-null   object
#  3   GarageYrBlt    1430 non-null   float64
#  4   GarageFinish   1430 non-null   object
#  5   GarageCars     1430 non-null   int64
#  6   PavedDrive     1430 non-null   object
#  7   WoodDeckSF     1430 non-null   int64
#  8   OpenPorchSF    1430 non-null   int64
#  9   EnclosedPorch  1430 non-null   int64
#  10  3SsnPorch      1430 non-null   int64
#  11  ScreenPorch    1430 non-null   int64
#  12  PoolArea       1430 non-null   int64
#  13  PoolQC         1430 non-null   int64
#  14  Fence          1430 non-null   object
#  15  MiscFeature    1430 non-null   object
#  16  MiscVal        1430 non-null   int64
# ...

# %% [markdown]
# #### Prepare data for modeling

# %%
X = df.drop(columns='SalePrice')
y = df.iloc[:, -2]

# %%
A = X.select_dtypes(['int', 'float']) #Variables numericas
B = pd.get_dummies(X.select_dtypes('object')) #Codificación de las categoricas
X_new = pd.concat([A,B],axis=1)
X_new
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLw  \
# ...

# %% [markdown]
# #### Split the dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y, test_size=0.2, random_state=42) #Separación de los datos de entrenamiento y prueba

# %% [markdown]
# Let's call linea regression

# %%
regressor = LinearRegression()

# %%
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_) #Revisamos el intercepto.
# Out:
# 76878.00943016587

# %%
print(regressor.coef_) #Revisamos coeficiente
# Out:
# [-6.29531219e-01 -4.27459373e+01  6.78786103e+00  1.44765970e+00
#   8.96027674e+03  4.74637620e+03  2.64831788e+02  3.88951164e+01
#   1.91480960e+01  6.23227163e+03  2.38834685e+03 -2.03685608e+01
#   2.86783201e+01  1.30030157e+03 -1.76496928e+03  5.52597302e+01
#   5.96663042e+03 -1.04577712e+03  5.53408536e+03 -7.56140788e+02
#   3.64859035e+01  8.86391071e+03  1.72785268e+01  3.33633413e+01
#   1.82990095e+01  4.22985056e+01  3.30547277e+01  1.05506257e+02
#  -1.41954511e+04  9.24020874e+00 -4.44594337e+02  2.62985498e+03
#  -2.54967714e+04  8.70331909e+03  8.58314978e+03  6.22974523e+03
#   1.98055728e+03 -2.83417485e+03  2.83417485e+03  1.45958463e+02
#   4.89488514e+02 -6.35446977e+02 -1.76631504e+03  4.61550193e+03
#  -3.14887283e+03  2.99685944e+02 -2.25082651e+03  9.22765212e+03
#  -6.64869216e+03 -3.28133450e+02  2.21869851e+03  8.47062195e+03
#  -3.04619544e+03 -1.10579455e+04  3.41482048e+03  1.83477778e+03
# ...

# %%
y_pred = regressor.predict(X_test) #Predecimos los valores
y_pred.shape
# Out:
# (72,)

# %%
r2_score(y_test, y_pred) #Calculamos el r2
# Out:
# 0.8904925826256986

# %%
rmselr = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred)) # MAE
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred))) # RMSE
print('Meadian Absolute Error:', metrics.median_absolute_error(y_test,y_pred)) #MAE
# Out:
# Mean Absolute Error: 16927.382681779174
# Root Mean Squared Error: 22770.828299969104
# Meadian Absolute Error: 14618.640625341432

# %% [markdown]
# RFR

# %%
#Creamos el modelo
model = RandomForestRegressor()
scores = cross_val_score(model, X_new, y, cv=7, verbose=1,scoring='r2') #Le indicamos al Cross_val el modelo, los datos, las veces que iterará (7 veces) y la metrica r2
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   10.0s finished

# %%
random_forest_nuevo = RandomForestRegressor(max_depth=18, max_features= 18, n_estimators=900) #Instanciamos el modelo

# %%
random_forest_nuevo.fit(X_train,y_train) #Ajustamos los datos
# Out:
# RandomForestRegressor(max_depth=18, max_features=18, n_estimators=900)

# %%
pred = random_forest_nuevo.predict(X_test)

# %%
scores = cross_val_score(random_forest_nuevo, X_new, y, cv=7, verbose=1,scoring='r2') #Le indicamos al Cross_val el modelo, los datos, las veces que iterará (7 veces) y la metrica r2
scores
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   11.0s finished
# array([0.86053988, 0.89863617, 0.86402905, 0.86603828, 0.90338169,
#        0.87076478, 0.84259282])

# %%
rmserf = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('R2: ',r2_score(y_true= y_test, y_pred= pred))
# Out:
# RMSE: 22182.94965493434
# R2:  0.8960739390856853

# %%
#Mostramos el resultado de r2 para las 7 iteraciones.
scores
# Out:
# array([0.85389655, 0.91849885, 0.90881678, 0.86323043, 0.91363172,
#        0.87616316, 0.83754527])

# %%
print("%0.2f mean r2, and standard deviation %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.82 mean r2, and standard deviation 0.04

# %%
model.fit(X_train,y_train) #Ajustamos los datos
# Out:
# RandomForestRegressor(max_depth=4, n_estimators=10, random_state=42)

# %%
pred = model.predict(X_test)

# %%
rmserf = np.sqrt(metrics.mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, pred)))
print('R2: ',r2_score(y_true= y_test, y_pred= pred))
# Out:
# RMSE: 25556.095838876598
# R2:  0.8620648676983129

# %% [markdown]
# #### Gradient Boosting

# %%
gbr = GradientBoostingRegressor()

# %%
scores = cross_val_score(gbr, X_new, y, cv=10, verbose=1,scoring='r2') #Le indicamos al Cross_val el modelo, los datos, las veces que iterará (7 veces) y la metrica r2
scores
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    4.7s finished
# array([0.9142187 , 0.90380532, 0.93796994, 0.91392636, 0.87851234,
#        0.92668544, 0.90645323, 0.90810797, 0.90695453, 0.87733397])

# %% [markdown]
# Let's use GridSearchCV

# %%
param_grid = {'max_depth' : [3, 7, 9],
              'n_estimators' : [10, 50, 100, 500],
              'learning_rate' : [0.0001, 0.001, 0.01, 0.1, 1.0],
              'subsample' : [0.5, 0.7, 1]}

grid_gb = GridSearchCV(estimator = gbr,
                                  param_grid = param_grid,
                                  cv = 10, 
                                  n_jobs = -1) # corrida en paralelo

# %%
grid_gb.fit(X_train, y_train)

# %%
grid_gb.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500, 'subsample': 0.5}

# %%
gbr_new = GradientBoostingRegressor(n_estimators=3500, 
    learning_rate=0.01,
    max_depth= 2, 
    subsample=0.7,
    min_samples_leaf=2)

# %%
scores = cross_val_score(gbr_new, X_new, y, cv=10, verbose=1,scoring='r2') #Le indicamos al Cross_val el modelo, los datos, las veces que iterará (7 veces) y la metrica r2
scores
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.4min finished
# array([0.91889933, 0.90723658, 0.95478336, 0.91827756, 0.90032204,
#        0.91117678, 0.91743499, 0.93006712, 0.919102  , 0.88841899])

# %%
gbr_new.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(learning_rate=0.01, max_depth=2, min_samples_leaf=2,
#                           n_estimators=3500, subsample=0.7)

# %%
ypredi = gbr_new.predict(X_test)

# %%
rmsegb = np.sqrt(mean_squared_error(y_test, ypredi))
print('RMSE: ', rmsegb)
print('R2: ',r2_score(y_true= y_test, y_pred= ypredi))
# Out:
# RMSE:  21560.59628605224
# R2:  0.9082918610850819

# %% [markdown]
# XGBOOST

# %%
xgb = XGBRegressor(n_estimators = 10000, max_depth = 2, eta = 0.01, min_child_weight = 0, subsample = 0.3, colsample_bytree=0.3, seed=5)

# %%
scores = cross_val_score(xgb, X_new, y, cv=7, verbose=1,scoring='r2') #Le indicamos al Cross_val el modelo, los datos, las veces que iterará (7 veces) y la metrica r2
scores
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:  2.1min finished
# array([0.90098825, 0.93411248, 0.924815  , 0.90801154, 0.92020326,
#        0.92826787, 0.90742175])

# %%
print("%0.2f mean r2, and standard deviation %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.92 mean r2, and standard deviation 0.01

# %%
xgb.fit(X_train, y_train) #Ajustamos los datos
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.3, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.01, eval_metric=None,
#              feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=0, missing=nan,
#              monotone_constraints=None, n_estimators=10000, n_jobs=None,
#              num_parallel_tree=None, predictor=None, ...)

# %%
bpred = xgb.predict(X_test)

# %%
rmsexg = np.sqrt(mean_squared_error(y_test, bpred))
print('RMSE: ', rmsexg)
print('R2: ',r2_score(y_true= y_test, y_pred= bpred))
# Out:
# RMSE:  21701.943517336073
# R2:  0.9005320569167563

# %% [markdown]
# CATBOOST

# %%
model = cb.CatBoostRegressor(loss_function='RMSE')

# %%
grid = {'iterations': [200, 400, 500, 700, 800],
        'learning_rate': [0.03, 0.1, 0.01],
        'depth': [2, 4, 6, 8],
        'l2_leaf_reg': [0.2, 0.5, 1, 3],
       'min_child_samples': [1, 4, 8, 16, 32]}

model.grid_search(grid, X_train, y_train)
# Out:
# 0:	learn: 185025.2976032	test: 187593.2448047	best: 187593.2448047 (0)	total: 61.3ms	remaining: 6.06s
# 1:	learn: 179954.6949271	test: 182501.5995840	best: 182501.5995840 (1)	total: 62.3ms	remaining: 3.05s
# 2:	learn: 174952.5947156	test: 177398.8313599	best: 177398.8313599 (2)	total: 63.5ms	remaining: 2.05s
# 3:	learn: 170519.2550448	test: 172972.7351935	best: 172972.7351935 (3)	total: 64.4ms	remaining: 1.54s
# 4:	learn: 165839.6978079	test: 168230.4087264	best: 168230.4087264 (4)	total: 65.2ms	remaining: 1.24s
# 5:	learn: 161429.3821952	test: 163793.5519776	best: 163793.5519776 (5)	total: 66.3ms	remaining: 1.04s
# 6:	learn: 157174.3585918	test: 159587.3405573	best: 159587.3405573 (6)	total: 67.4ms	remaining: 895ms
# 7:	learn: 152895.8800413	test: 155361.6700023	best: 155361.6700023 (7)	total: 68.9ms	remaining: 793ms
# 8:	learn: 148764.0355484	test: 151084.4154543	best: 151084.4154543 (8)	total: 69.7ms	remaining: 704ms
# ...

# %%
model_new = cb.CatBoostRegressor(iterations = 900,
        learning_rate = 0.1,
        depth = 4,
        l2_leaf_reg = 1)

# %%
model_new.fit(X_train, y_train)
# Out:
# 0:	learn: 66709.2087053	total: 2.78ms	remaining: 2.5s
# 1:	learn: 62284.1060057	total: 3.81ms	remaining: 1.71s
# 2:	learn: 58636.2097790	total: 4.64ms	remaining: 1.39s
# 3:	learn: 55117.3882585	total: 5.41ms	remaining: 1.21s
# 4:	learn: 52195.9883906	total: 6.36ms	remaining: 1.14s
# 5:	learn: 49365.0756854	total: 7.37ms	remaining: 1.1s
# 6:	learn: 46826.8323507	total: 8.31ms	remaining: 1.06s
# 7:	learn: 44606.9101014	total: 9.13ms	remaining: 1.02s
# 8:	learn: 42351.3330794	total: 10.6ms	remaining: 1.04s
# 9:	learn: 40646.5626183	total: 12.1ms	remaining: 1.07s
# 10:	learn: 38796.4431659	total: 13.3ms	remaining: 1.07s
# 11:	learn: 37126.2450869	total: 14.3ms	remaining: 1.05s
# 12:	learn: 35757.1620298	total: 15.3ms	remaining: 1.05s
# 13:	learn: 34287.2871441	total: 16.3ms	remaining: 1.03s
# 14:	learn: 33014.1311945	total: 17.3ms	remaining: 1.02s
# 15:	learn: 32081.4448610	total: 19ms	remaining: 1.05s
# 16:	learn: 31109.9888597	total: 20.1ms	remaining: 1.04s
# ...

# %%
predc = model_new.predict(X_test)
rmsecat = (np.sqrt(mean_squared_error(y_test, predc)))
r2 = r2_score(y_test, predc)
print('Testing performance')
print('RMSE: {:.2f}'.format(rmse))
print('R2: {:.2f}'.format(r2))
# Out:
# Testing performance
# RMSE: 21645.56
# R2: 0.91

# %%
df_comparacion = pd.DataFrame({
                    'modelo': ['RandomFR', 'GradientBoost', 'XGBOOST', 'CatBoost'],
                    'test rmse': [rmserf, rmsegb, rmsexg, rmsecat]
                 }).sort_values(by='test rmse', ascending=False)

fig, ax = plt.subplots(figsize=(5, 4))
df_comparacion.set_index('modelo').plot(kind='barh', ax=ax, color='steelblue')
ax.set_xlabel('RMSE')
ax.set_ylabel('Model')
ax.set_title('Comparasion');

# %%
df_test = pd.read_csv('/Users/jesuslopez/Downloads/test.csv')
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
df_test = df_test.fillna(df_test.select_dtypes(include=['float64']).median())
df_test.Alley = df_test.Alley.fillna('NoAll')
df_test.Electrical = df_test.Electrical.fillna('SBrkr') #To the most common electrical system
df_test.BFireplaceQu = df_test.FireplaceQu.fillna('None')
df_test.BsmtQual = df_test.BsmtQual.fillna('None')
encoder = ce.OrdinalEncoder(cols=['BsmtQual'],return_df=True,
                           mapping=[{'col':'BsmtQual',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df_test['BsmtQual'] = encoder.fit_transform(df_test['BsmtQual'])
encoder = ce.OrdinalEncoder(cols=['FireplaceQu'],return_df=True,
                           mapping=[{'col':'FireplaceQu',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df_test['FireplaceQu'] = encoder.fit_transform(df_test['FireplaceQu'])
df_test.GarageType = df_test.GarageType.fillna('NG') #NaN mean No garage, so let's replace with NG = No Garage
df_test.GarageFinish = df_test.GarageFinish.fillna('NG') #NaN mean No garage, so let's replace with NG = No Garage
df_test.PoolQC = df_test.PoolQC.fillna('None')
encoder = ce.OrdinalEncoder(cols=['PoolQC'],return_df=True,
                           mapping=[{'col':'PoolQC',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df_test['PoolQC'] = encoder.fit_transform(df_test['PoolQC'])
df_test.ExterQual = df_test.ExterQual.fillna('None')
encoder = ce.OrdinalEncoder(cols=['ExterQual'],return_df=True,
                           mapping=[{'col':'ExterQual',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df_test['ExterQual'] = encoder.fit_transform(df_test['ExterQual'])
df_test.HeatingQC = df_test.HeatingQC.fillna('None')
encoder = ce.OrdinalEncoder(cols=['HeatingQC'],return_df=True,
                           mapping=[{'col':'HeatingQC',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df_test['HeatingQC'] = encoder.fit_transform(df_test['HeatingQC'])
df_test.KitchenQual = df_test.KitchenQual.fillna('None')
encoder = ce.OrdinalEncoder(cols=['KitchenQual'],return_df=True,
                           mapping=[{'col':'KitchenQual',
'mapping':{'None':0, 'Po':1, 'Fa':2, 'TA':3, 'Gd':4, 'Ex':5}}])
df_test['KitchenQual'] = encoder.fit_transform(df_test['KitchenQual'])
encoder = ce.OrdinalEncoder(cols=['CentralAir'],return_df=True,
                           mapping=[{'col':'CentralAir',
'mapping':{'N':0, 'Y':1}}])
df_test['CentralAir'] = encoder.fit_transform(df_test['CentralAir'])
df_test.Fence = df_test.Fence.fillna('NoF')
df_test.MiscFeature = df_test.MiscFeature.fillna('None')
df_test.MasVnrType = df_test.MasVnrType.fillna('None')
df_test['TotalBath'] = df_test[['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath']].sum(axis=1)
df_test = df_test.drop(columns=['BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BedroomAbvGr', 'KitchenAbvGr', 'GarageArea', 'GarageQual', 'GarageCond', 'MoSold', 'Utilities'])

# %%
df_test.Exterior1st = df_test.Exterior1st.fillna('VinylSd')
df_test.MSZoning = df_test.MSZoning.fillna('RL')
df_test.Exterior2nd = df_test.Exterior2nd.fillna('VinylSd')
df_test.Functional = df_test.Functional.fillna('Typ')
df_test.SaleType = df_test.SaleType.fillna('WD')

# %%
X = df_test

# %%
A = df_test.select_dtypes(['int', 'float']) #Variables numericas
B = pd.get_dummies(df_test.select_dtypes('object')) #Codificación de las categoricas
X_new_test = pd.concat([A,B],axis=1) #Unir nuevamente las columnas, teniendo las categoricas ya codificadas
X_new_test
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0     1461          20         80.0    11622            5            6
# 1     1462          20         81.0    14267            6            6
# 2     1463          60         74.0    13830            5            5
# 3     1464          60         78.0     9978            6            6
# 4     1465         120         43.0     5005            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1454  2915         160         21.0     1936            4            7
# 1455  2916         160         21.0     1894            4            5
# 1456  2917          20        160.0    20000            5            7
# 1457  2918          85         62.0    10441            5            5
# 1458  2919          60         74.0     9627            7            5
#
#       YearBuilt  YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLw  \
# ...

# %%
my_list = X_new_test.columns.values
np.savetxt("list2.csv", 
           my_list,
           delimiter =", ", 
           fmt ='% s')

# %%
X_new_test[['Condition2_RRAe', 'Condition2_RRAn', 'Condition2_RRNn', 'HouseStyle_2.5Fin', 'RoofMatl_Metal', 'RoofMatl_Roll', 'Exterior1st_ImStucc', 'Exterior1st_Stone', 'Exterior2nd_Other', 'Heating_Floor', 'Heating_OthW', 'Electrical_Mix', 'MiscFeature_TenC']] = 0

# %%
copydf = X_new_test.copy()
copydf = copydf.values

# %%
df_test['SalePrice'] = model_new.predict(X_new_test)

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave  NoAll      Reg
# 1     1462          20       RL         81.0    14267   Pave  NoAll      IR1
# 2     1463          60       RL         74.0    13830   Pave  NoAll      IR1
# 3     1464          60       RL         78.0     9978   Pave  NoAll      IR1
# 4     1465         120       RL         43.0     5005   Pave  NoAll      IR1
# ...    ...         ...      ...          ...      ...    ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave  NoAll      Reg
# 1455  2916         160       RM         21.0     1894   Pave  NoAll      Reg
# 1456  2917          20       RL        160.0    20000   Pave  NoAll      Reg
# 1457  2918          85       RL         62.0    10441   Pave  NoAll      Reg
# 1458  2919          60       RL         74.0     9627   Pave  NoAll      Reg
#
# ...

# %%
df_test[['Id', 'SalePrice']].to_csv('test9.csv', index=False)
